# %% [markdown]
# ## Temprature Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
benin = pd.read_csv("/Users/Suraphel/Desktop/Week-0/Optimal-Solar-Investment-Analysis/notebooks/benin.csv")
sierraleone = pd.read_csv("/Users/Suraphel/Desktop/Week-0/Optimal-Solar-Investment-Analysis/notebooks/sierraleone.csv")
togo = pd.read_csv("/Users/Suraphel/Desktop/Week-0/Optimal-Solar-Investment-Analysis/notebooks/togo.csv")

# %%
def avg_temp(data):
    data['Temperature'] = (data['TModA'] + data['TModB']) / 2

def analyze_temp_and_rh(data,city):
    # Create a new column for average temperature
    
    fig, ax1 = plt.subplots()

    color = 'tab:red'
    ax1.set_xlabel('Timestamp')
    ax1.set_ylabel('Temperature (C)', color=color)
    ax1.plot(data['Timestamp'], data['Temperature'], color=color, linewidth=0.5)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()
    color = 'tab:blue'
    ax2.set_ylabel('Relative Humidity (%)', color=color)
    ax2.plot(data['Timestamp'], data['RH'], color=color, linewidth=0.5)
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()
    plt.title(f'Temperature and Relative Humidity Over Time for {city}')
    plt.show()

# %%
# create average temprature for every city based on the on taking the average of model A and model B
avg_temp(benin)
avg_temp(sierraleone)
avg_temp(togo)

# %%
# since it take a lot of time I decrease the size of the sample 
analyze_temp_and_rh(benin.head(10000),'Benin')

# %%
analyze_temp_and_rh(sierraleone.head(1000),'Sierraleone')

# %%
analyze_temp_and_rh(togo.head(1000),'Togo')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The temperature analysis was conducted by creating a method that analyzes temperature and relative humidity data from the given dataset. A new column for the average temperature was generated by combining the 'TModA' and 'TModB' values. A graph was plotted to compare temperature and humidity over time, providing insights into their relationship. This analysis was successfully applied to the datasets for Benin, Sierra Leone, and Togo, helping to observe trends and correlations in temperature and humidity across the three cities.
